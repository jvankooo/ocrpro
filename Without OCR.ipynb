# %%
import fitz  # PyMuPDF
import pdfplumber
import pandas as pd
import os
from collections import Counter

# File path
pdf_path = "Phable CAM Final.pdf"

# Extract text using PyMuPDF
doc = fitz.open(pdf_path)
text_content = ""
metadata = doc.metadata
image_count = 0

# Extract images
image_dir = "extracted_images"
os.makedirs(image_dir, exist_ok=True)

for i, page in enumerate(doc):
    text_content += page.get_text("text") + "\n\n"
    
    # Extract images
    for img_index, img in enumerate(page.get_images(full=True)):
        xref = img[0]
        base_image = doc.extract_image(xref)
        image_data = base_image["image"]
        image_ext = base_image["ext"]
        img_filename = f"{image_dir}/image_{i+1}_{img_index+1}.{image_ext}"
        with open(img_filename, "wb") as img_file:
            img_file.write(image_data)
        image_count += 1

# Extract tables using pdfplumber
table_count = 0
tables = []

with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        extracted_tables = page.extract_tables()
        for table in extracted_tables:
            df = pd.DataFrame(table).replace("", None)  # Convert empty strings to None
            
            # Heuristic filters to discard false tables
            if df.isnull().sum().sum() > 0.8 * df.size:  # Too many empty cells
                continue
            if df.shape[1] == 1 or df.shape[0] < 2:  # Single-column/row noise
                continue
            if df.applymap(lambda x: isinstance(x, str) and len(x.strip()) > 50).sum().sum() > 0.9 * df.size:
                continue  # Rejects text blocks misclassified as tables
            
            tables.append(df.values.tolist())
            table_count += len(extracted_tables)

# Count extracted elements
data_summary = Counter({"text_pages": len(doc), "tables": table_count, "images": image_count})

# Save extracted text
text_output_path = "extracted_text.txt"
with open(text_output_path, "w", encoding="utf-8") as text_file:
    text_file.write(text_content)

# Save extracted tables as JSON
import json
table_output_path = "extracted_tables.json"
with open(table_output_path, "w", encoding="utf-8") as json_file:
    json.dump(tables, json_file, indent=4)

# Output results
metadata, data_summary, text_output_path, table_output_path, image_dir
# Out:
# C:\Users\chira\AppData\Local\Temp\ipykernel_21852\2615977509.py:49: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   if df.applymap(lambda x: isinstance(x, str) and len(x.strip()) > 50).sum().sum() > 0.9 * df.size:
# ({'format': 'PDF 1.4',
#   'title': '',
#   'author': '',
#   'subject': '',
#   'keywords': '',
#   'creator': '',
#   'producer': 'iOS Version 15.1 (Build 19B74) Quartz PDFContext',
#   'creationDate': "D:20211206105506Z00'00'",
#   'modDate': "D:20211206105506Z00'00'",
#   'trapped': '',
#   'encryption': None},
#  Counter({'tables': 106, 'images': 97, 'text_pages': 35}),
#  'extracted_text.txt',
#  'extracted_tables.json',
#  'extracted_images')

# %%
import json

# Save extracted tables in JSON format
tables_json_path = "extracted_tables.json"

with open(tables_json_path, "w", encoding="utf-8") as json_file:
    json.dump(tables, json_file, indent=4)

# Output table extraction result
tables_json_path
# Out:
# 'extracted_tables.json'

# %%
# Read and display extracted text
text_file = "extracted_text.txt"  # Update path if needed

with open(text_file, "r", encoding="utf-8") as file:
    extracted_text = file.read()

print(extracted_text[:2000])  # Display first 2000 characters (adjust as needed)
# Out:
#
#
#
# 1
#
# Proposal Summary                                                                                                                              December, 2021
# Borrower Name:  Terrals Technologies Pvt. Ltd.
# Sector: Chronic Disease Management and Healthcare Services Platform
# Proposed Amount: Up to INR 45,00,00,000
# Tranche 1: INR 10,00,00,000
# Tranche 2: Up to 15% of the equity raise (Series B) with an overall cap of INR 35Cr
# Tenor: 18 months from the date of disbursement of each tranche
# Debt XIRR: 16.56%; Warrants: 7%; XIRR with warrant upside: 31.2%
# Repayment Schedule:
# Quarterly Amortization (5 instalments); Moratorium for three months i.e., first principal instalment at the end of 6
# months. The coupons are to be serviced monthly on the last day of each month.
# Filtering Criteria:
# Criteria
# Stride Filter
# Pre-Equity
# Post-Equity*
# Equity Raised till Date
# > INR 50Cr
# INR 64Cr
# INR 192 Cr
# Debt/Equity Raised (incl. proposed
# debt)
# < 15%
# 15.9%
# 15.16%(1)(2)
# Debt/Valuation (incl. proposed debt)
# <5%
# 6.6%
# NA(3)
# Months of Runway (excl. proposed debt)
# >9
# >3(1)
# >18
# Revenue
# ARR > INR 25Cr
# INR 95 Cr
# *Assumed only $17M Series B takes place.
# Notes: 7KHFRPSDQ\LVUDLVLQJ6HULHV%RI0Q,15&UZLWKHTXLW\LQIXVLRQH[SHFWHGLQ'HF·6HFRQGFORVLQJRI
# this round is expected by the end of January 2022 & may go as high as $40 Mn cumulatively.
# (2) The company is raising significant debt and equity to finance strategic acquisitions.
# (3) The current Series B round will be a convertible round valued at 20% discount to series C (expected to close Q1 FY23)
# Cash Margin: 7.5% of Investment Amount
# Security:
# ¾ First charge and hypothecation on all existing and future fixed, current and intangible assets of the Borrower
# for each tranche.
# ¾ 6 Undated Cheques & NACH Mandate.
# Financial Covenants:
# ¾ 6 months average monthly cash burn to be maintained in Cash & Cash Equivalents
# ¾ Debt/

# %%
import os
from PIL import Image
from IPython.display import display

# Define the directory where extracted images are stored
image_dir = "extracted_images"  # Adjust path if necessary

# Check if the directory exists
if not os.path.exists(image_dir):
    print(f"Directory '{image_dir}' not found. Make sure the extraction was successful.")
else:
    # List all image files in the directory
    image_files = [f for f in os.listdir(image_dir) if f.lower().endswith((".png", ".jpg", ".jpeg"))]

    if not image_files:
        print("No images found in the directory.")
    else:
        print(f"Found {len(image_files)} images. Displaying the first one...")
        
        # Open and display the first image
        img_path = os.path.join(image_dir, image_files[0])
        img = Image.open(img_path)
        display(img)
# Out:
# Found 97 images. Displaying the first one...
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=172x68>

# %%
import json
import pandas as pd
import os

# Load the extracted tables from the JSON file
json_path = "extracted_tables.json"  # Adjust path if necessary
with open(json_path, "r", encoding="utf-8") as f:
    tables = json.load(f)


#  Save all tables into a single Excel workbook with multiple sheets
excel_path = "readable_tables.xlsx"
with pd.ExcelWriter(excel_path) as writer:
    for i, table in enumerate(tables):
        df = pd.DataFrame(table)
        sheet_name = f"Table_{i+1}"
        df.to_excel(writer, sheet_name=sheet_name, index=False, header=False)
print(f"All tables have been saved in the Excel file: {excel_path}")
# Out:
# All tables have been saved in the Excel file: readable_tables.xlsx

# %%
import pandas as pd

# Path to the Excel file
file_path = "readable_tables.xlsx"

# Load the workbook and get sheet names
xls = pd.ExcelFile(file_path)
print("Available Sheets:", xls.sheet_names)

# Read all sheets into a dictionary of DataFrames
dfs = pd.read_excel(file_path, sheet_name=None)

# Display first few rows from each sheet
for sheet, df in dfs.items():
    print(f"\nSheet Name: {sheet}")
    print(df.head())  # Display first 5 rows
# Out:
# Available Sheets: ['Table_1', 'Table_2', 'Table_3', 'Table_4', 'Table_5', 'Table_6', 'Table_7', 'Table_8', 'Table_9', 'Table_10', 'Table_11', 'Table_12', 'Table_13', 'Table_14', 'Table_15', 'Table_16', 'Table_17', 'Table_18', 'Table_19', 'Table_20', 'Table_21', 'Table_22', 'Table_23', 'Table_24', 'Table_25', 'Table_26', 'Table_27', 'Table_28', 'Table_29', 'Table_30', 'Table_31', 'Table_32', 'Table_33']
#
# Sheet Name: Table_1
#                                           Unnamed: 0  \
# 0  Borrower Name: Terrals Technologies Pvt. Ltd.\...
#
#    Proposal Summary December, 2021
# 0                              NaN
#
# Sheet Name: Table_2
#                                   Unnamed: 0  Criteria  Unnamed: 2  \
# 0                    Equity Raised till Date       NaN         NaN
# 1  Debt/Equity Raised (incl. proposed\ndebt)       NaN         NaN
# 2       Debt/Valuation (incl. proposed debt)       NaN         NaN
# 3     Months of Runway (excl. proposed debt)       NaN         NaN
# 4                                    Revenue       NaN         NaN
#
#        Unnamed: 3  Stride Filter  Unnamed: 5 Unnamed: 6  Pre-Equity  \
# 0      > INR 50Cr            NaN         NaN   INR 64Cr         NaN
# 1           < 15%            NaN         NaN      15.9%         NaN
# 2             <5%            NaN         NaN       6.6%         NaN
# 3              >9            NaN         NaN      >3(1)         NaN
# 4  ARR > INR 25Cr            NaN         NaN  INR 95 Cr         NaN
#
#    Unnamed: 8    Unnamed: 9  Post-Equity*
# 0         NaN    INR 192 Cr           NaN
# 1         NaN  15.16%(1)(2)           NaN
# 2         NaN         NA(3)           NaN
# 3         NaN           >18           NaN
# 4         NaN           NaN           NaN
#
# Sheet Name: Table_3
#   (cid:190) Company to share all notices, board minutes & other necessary board meeting material to Stride Ventures\nwithin 7 days from such board meeting.\nPartly Paid CCPS Valuation:\nInvestor shall be entitled to subscribe to partly paid-up shares to the extent of 7% of the Investment Amount, which\nwhen exercised at any time during the Exercise Period (5 years from the Maturity date of the last tranche or end of the\nfund life, whichever is later.), shall convert into equivalent equity shares of the Borrower at par to the per share price\nof Series B i.e., 20% discount to Series C.  \
# 0                                                NaN
# 1  Shareholding Pattern:\nAmount\nShareholding Pa...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Unnamed: 1
# 0                              Promoters & Cap Table
# 1                                                NaN
# 2                              Shareholding Pattern:
# 3                                                NaN
# 4  Amount\nShareholding Pattern of Terrals Techno...
#
# Sheet Name: Table_4
#    Institution / Individual          Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                       NaN                 NaN         NaN         NaN
# 1                       NaN  Founders/Promoters         NaN         NaN
# 2                       NaN         Sumit Sinha         NaN         NaN
# 3                       NaN       Mukesh Bansal         NaN         NaN
# 4                       NaN        Institutions         NaN         NaN
#
#   Investor  Unnamed: 5  Fund Details Unnamed: 7  Unnamed: 8  Shareholding  \
# 0    Since         NaN           NaN        NaN         NaN           NaN
# 1      NaN         NaN           NaN        NaN         NaN           NaN
# 2     2018         NaN           NaN        NaN         NaN           NaN
# 3     2018         NaN           NaN        NaN         NaN           NaN
# 4      NaN         NaN           NaN        NaN         NaN           NaN
#
#   Unnamed: 10
# 0         NaN
# 1         NaN
# 2      19.84%
# 3      14.38%
# 4         NaN
#
# Sheet Name: Table_5
#    Unnamed: 0         Department  Unnamed: 2  Unnamed: 3  # of Employees
# 0         NaN           Founders         NaN         NaN               2
# 1         NaN            Finance         NaN         NaN               6
# 2         NaN            Digital         NaN         NaN              14
# 3         NaN            Product         NaN         NaN              16
# 4         NaN  Management Office         NaN         NaN              21
#
# Sheet Name: Table_6
#   Funding\nDate Unnamed: 1  Unnamed: 2     Round Unnamed: 4  Unnamed: 5  \
# 0           NaN        NaN         NaN       NaN        NaN         NaN
# 1           NaN        NaN         NaN       NaN        NaN         NaN
# 2        Jan-21        NaN         NaN  Series A        NaN         NaN
# 3           NaN        NaN         NaN       NaN        NaN         NaN
# 4        Jan-20        NaN         NaN      Seed        NaN         NaN
#
#    Unnamed: 6 Investment  Unnamed: 8  Unnamed: 9 Post Money  Unnamed: 11  \
# 0         NaN     Amount         NaN         NaN  Valuation          NaN
# 1         NaN   (INR Cr)         NaN         NaN   (INR Cr)          NaN
# 2        50.5        NaN         NaN       150.0        NaN          NaN
# 3         NaN        NaN         NaN         NaN        NaN          NaN
# 4        10.3        NaN         NaN        45.0        NaN          NaN
#
#    Investors                             Unnamed: 13
# 0        NaN                                     NaN
# 1        NaN                                     NaN
# 2        NaN  Kalaari Capital, SOSV, Fresco, Manipal
# 3        NaN         Hospitals, Omron, Social Starts
# 4        NaN   SOSV, Betatron, Fresco, Lets Venture,
#
# Sheet Name: Table_7
#    SNo.  Unnamed: 1  Unnamed: 2  Company Name   Unnamed: 4  Unnamed: 5  \
# 0   NaN         NaN         NaN           NaN          NaN         NaN
# 1   NaN         1.0         NaN           NaN     Dream 11         NaN
# 2   NaN         2.0         NaN           NaN     Cult.Fit         NaN
# 3   NaN         3.0         NaN           NaN      MedPlus         NaN
# 4   NaN         4.0         NaN           NaN  Elastic Run         NaN
#
#    Unnamed: 6 Founded  Unnamed: 8  City Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0         NaN    Year         NaN   NaN         NaN          NaN          NaN
# 1         NaN    2008         NaN   NaN      Mumbai          NaN          NaN
# 2         NaN    2016         NaN   NaN   Bangalore          NaN          NaN
# 3         NaN    2006         NaN   NaN   Hyderabad          NaN          NaN
# 4         NaN    2016         NaN   NaN        Pune          NaN          NaN
#
#   Total Funding  Unnamed: 14  Unnamed: 15   Company  Unnamed: 17  Unnamed: 18  \
# 0  (INR Crores)          NaN          NaN     Stage          NaN          NaN
# 1         5,888          NaN          NaN  Series F          NaN          NaN
# 2         3,698          NaN          NaN  Series D          NaN          NaN
# 3         2,018          NaN          NaN  Series C          NaN          NaN
# 4           975          NaN          NaN  Series D          NaN          NaN
#
#   Latest Valuation
# 0     (INR Crores)
# 1           37,500
# 2            6,060
# 3            3,195
# 4            3,015
#
# Sheet Name: Table_8
#    SNo.  Unnamed: 1  Unnamed: 2  Company Name  Unnamed: 4  Unnamed: 5  \
# 0   NaN         NaN         NaN           NaN         NaN         NaN
# 1   NaN         1.0         NaN           NaN    CoutLoot         NaN
# 2   NaN         2.0         NaN           NaN        Toch         NaN
# 3   NaN         3.0         NaN           NaN    Vidyakul         NaN
# 4   NaN         4.0         NaN           NaN  ClearDekho         NaN
#
#    Unnamed: 6 Founded  Unnamed: 8  City Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0         NaN    Year         NaN   NaN         NaN          NaN          NaN
# 1         NaN    2016         NaN   NaN      Mumbai          NaN          NaN
# 2         NaN    2016         NaN   NaN      Mumbai          NaN          NaN
# 3         NaN    2017         NaN   NaN     Gurgaon          NaN          NaN
# 4         NaN    2015         NaN   NaN   Ghaziabad          NaN          NaN
#
#   Total Funding  Unnamed: 14  Unnamed: 15       Company  Unnamed: 17  \
# 0  (INR Crores)          NaN          NaN         Stage          NaN
# 1         311.3          NaN          NaN      Series A          NaN
# 2         102.0          NaN          NaN      Series A          NaN
# 3          38.4          NaN          NaN          Seed          NaN
# 4          62.1          NaN          NaN  Pre-Series A          NaN
#
#    Unnamed: 18 Latest Valuation
# 0          NaN     (INR Crores)
# 1          NaN             83.3
# 2          NaN            112.5
# 3          NaN             28.7
# 4          NaN             80.8
#
# Sheet Name: Table_9
#                                           Unnamed: 0  Business Profile
# 0  Introduction\nFounded in 2017, Phable is a chr...               NaN
#
# Sheet Name: Table_10
#                       Unnamed: 0 Unnamed: 1  Apr'21  Unnamed: 3 Unnamed: 4  \
# 0        Total Users (in\nLakhs)       4.02     NaN         NaN       4.67
# 1       Monthly Active\nPatients        69%     NaN         NaN        64%
# 2  Transacting users\n(% of MAU)         4%     NaN         NaN         4%
#
#    May'21  Unnamed: 6 Unnamed: 7  Jun'21  Unnamed: 9 Unnamed: 10  Jul'21  \
# 0     NaN         NaN       5.42     NaN         NaN        6.25     NaN
# 1     NaN         NaN        64%     NaN         NaN         64%     NaN
# 2     NaN         NaN         3%     NaN         NaN          3%     NaN
#
#   Unnamed: 12  Aug'21
# 0        7.41     NaN
# 1         63%     NaN
# 2          4%     NaN
#
# Sheet Name: Table_11
#     Unnamed: 0  Particulars\n(INR) Jun-\n20  Unnamed: 3 Unnamed: 4  Jul-  \
# 0          NaN                 NaN      NaN         NaN        NaN  20.0
# 1  Doctor\nCAC                 NaN   18,244         NaN      6,763   NaN
# 2    User CAC*                 NaN      241         NaN        154   NaN
#
#    Unnamed: 6   Aug- Unnamed: 8  Sep-\n20  ...  May-  Unnamed: 28 Unnamed: 29  \
# 0         NaN     20        NaN       NaN  ...  21.0          NaN         NaN
# 1         NaN  3,562      3,243       NaN  ...   NaN          NaN       4,182
# 2         NaN     83         93       NaN  ...   NaN          NaN          30
#
#    Jun-  Unnamed: 31 Unnamed: 32  Jul-.1 Unnamed: 34  Unnamed: 35 Aug-.1
# 0  21.0          NaN         NaN    21.0         NaN          NaN   21.0
# 1   NaN          NaN       3,483     NaN         NaN        3,351    NaN
# 2   NaN          NaN          39     NaN         NaN           45    NaN
#
# [3 rows x 37 columns]
#
# Sheet Name: Table_12
#   Unnamed: 0  Month of\nDownload #Users\nAdded  Unnamed: 3 Unnamed: 4  \
# 0        NaN                 NaN           NaN         NaN        NaN
# 1     Nov-20                 NaN        17,007         NaN       100%
# 2     Dec-20                 NaN        30,045         NaN        NaN
# 3     Jan-21                 NaN        42,848         NaN        NaN
# 4     Feb-21                 NaN        49,451         NaN        NaN
#
#    Nov-\n20 Unnamed: 6  Dec-  Unnamed: 8 Unnamed: 9  ...  Jul-  Unnamed: 24  \
# 0       NaN        NaN  20.0         NaN        NaN  ...  21.0          NaN
# 1       NaN        85%   NaN         NaN        67%  ...   NaN          NaN
# 2       NaN       100%   NaN         NaN        83%  ...   NaN          NaN
# 3       NaN        NaN   NaN         NaN       100%  ...   NaN          NaN
# 4       NaN        NaN   NaN         NaN        NaN  ...   NaN          NaN
#
#   Unnamed: 25  Aug-  Unnamed: 27 Unnamed: 28  Sep-  Unnamed: 30 Unnamed: 31  \
# 0         NaN  21.0          NaN         NaN  21.0          NaN         NaN
# 1         49%   NaN          NaN         47%   NaN          NaN         44%
# 2         49%   NaN          NaN         46%   NaN          NaN         43%
# 3         55%   NaN          NaN         50%   NaN          NaN         47%
# 4         64%   NaN          NaN         60%   NaN          NaN         58%
#
#    Oct-
# 0  21.0
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 33 columns]
#
# Sheet Name: Table_13
#   Unnamed: 0  Month of Unnamed: 2 #Users  Unnamed: 4 Unnamed: 5  Jan-  \
# 0        NaN  download        NaN  Added         NaN        NaN  21.0
# 1     Jan-21       NaN     26,768    NaN         NaN       100%   NaN
# 2     Feb-21       NaN     31,520    NaN         NaN        NaN   NaN
# 3     Mar-21       NaN     29,272    NaN         NaN        NaN   NaN
# 4     Apr-21       NaN     41,088    NaN         NaN        NaN   NaN
#
#    Unnamed: 7 Feb-\n21 Mar-\n21  ...  Jul- Unnamed: 19  Unnamed: 20  Aug-  \
# 0         NaN      NaN      NaN  ...  21.0         NaN          NaN  21.0
# 1         NaN      89%      83%  ...   NaN         NaN          74%   NaN
# 2         NaN     100%      92%  ...   NaN         NaN          74%   NaN
# 3         NaN      NaN     100%  ...   NaN         NaN          78%   NaN
# 4         NaN      NaN      NaN  ...   NaN         NaN          85%   NaN
#
#   Unnamed: 22 Unnamed: 23  Sep- Unnamed: 25  Unnamed: 26  Oct-
# 0         NaN         NaN  21.0         NaN          NaN    21
# 1         NaN         67%   NaN         NaN          NaN   63%
# 2         NaN         70%   NaN         NaN          NaN   67%
# 3         NaN         71%   NaN         NaN          NaN   66%
# 4         NaN         77%   NaN         NaN          NaN   70%
#
# [5 rows x 28 columns]
#
# Sheet Name: Table_14
#   Particulars Unnamed: 1  Nov-  Unnamed: 3 Unnamed: 4  Dec-  Unnamed: 6  \
# 0         NaN        NaN  20.0         NaN        NaN  20.0         NaN
# 1     DAU/MAU        14%   NaN         NaN        11%   NaN         NaN
# 2     WAU/MAU        27%   NaN         NaN        27%   NaN         NaN
#
#   Unnamed: 7  Jan-  Unnamed: 9  ...  Jul-  Unnamed: 27  Unnamed: 28  Aug-  \
# 0        NaN  21.0         NaN  ...  21.0          NaN          NaN  21.0
# 1        21%   NaN         NaN  ...   NaN          NaN          26%   NaN
# 2        44%   NaN         NaN  ...   NaN          NaN          37%   NaN
#
#    Unnamed: 30  Unnamed: 31  Sep-  Unnamed: 33  Unnamed: 34  Oct-
# 0          NaN          NaN  21.0          NaN          NaN  21.0
# 1          NaN          27%   NaN          NaN          28%   NaN
# 2          NaN          37%   NaN          NaN          40%   NaN
#
# [3 rows x 36 columns]
#
# Sheet Name: Table_15
#              Unnamed: 0  Doctor Name  Unnamed: 2  \
# 0  Dr. Oliver Rodrigues          NaN         NaN
#
#                                           Unnamed: 3  Description
# 0  Years of Experience: 13 years\nPractice Area: ...          NaN
#
# Sheet Name: Table_16
#           Dr. Vivek Baliga  \
# 0  Dr. Shrideep Arun Parab
# 1  Dr. Venkatesh Somalaram
# 2        Dr. Jivesh Singla
#
#   Years of Experience: 16 years\nPractice Area: Internal Medicine and Cardiologist\nWork Experience:\n(cid:190) Baliga Diagnostics, Bangalore\n(cid:190) Aster RV Hospital, Bangalore\n(cid:190) Fortis Hospital, Bangalore\n(cid:190) HeartSense, Bangalore\n(cid:190) Indian Academy of Echocardiography, Karnataka Chapter\nEducational Qualifications:\n(cid:190) MBBS, Kasturba Medical College, Mangalore (Class of 2000)\n(cid:190) MRCP, Royal College of Physicians (Class of 2006)
# 0  Years of Experience: 20 years\nPractice Area: ...
# 1  Years of Experience: 5 years\nPractice Area: C...
# 2  Years of Experience: 6 years\nPractice Area: I...
#
# Sheet Name: Table_17
#    Month Unnamed: 1  Unnamed: 2  #Doctors Unnamed: 4  Nov-  Unnamed: 6  \
# 0    NaN        NaN         NaN       NaN        NaN  20.0         NaN
# 1    NaN     Nov-20         NaN     169.0       100%   NaN         NaN
# 2    NaN     Dec-20         NaN     121.0        NaN   NaN         NaN
# 3    NaN     Jan-21         NaN      85.0        NaN   NaN         NaN
# 4    NaN     Feb-21         NaN     105.0        NaN   NaN         NaN
#
#   Unnamed: 7  Dec-  Unnamed: 9  ...  Jul-  Unnamed: 30  Unnamed: 31  Aug-  \
# 0        NaN  20.0         NaN  ...  21.0          NaN          NaN  21.0
# 1        85%   NaN         NaN  ...   NaN          NaN          68%   NaN
# 2       100%   NaN         NaN  ...   NaN          NaN          64%   NaN
# 3        NaN   NaN         NaN  ...   NaN          NaN          79%   NaN
# 4        NaN   NaN         NaN  ...   NaN          NaN          81%   NaN
#
#    Unnamed: 33  Unnamed: 34  Sep-  Unnamed: 36  Unnamed: 37  Oct-
# 0          NaN          NaN  21.0          NaN          NaN  21.0
# 1          NaN          65%   NaN          NaN          65%   NaN
# 2          NaN          64%   NaN          NaN          64%   NaN
# 3          NaN          74%   NaN          NaN          69%   NaN
# 4          NaN          75%   NaN          NaN          71%   NaN
#
# [5 rows x 39 columns]
#
# Sheet Name: Table_18
#            Unnamed: 0       Name  Unnamed: 2  \
# 0                 NaN    Date of         NaN
# 1                 NaN  Agreement         NaN
# 2  Scope of\nServices        NaN         NaN
#
#                                            Pharmeasy  \
# 0                                     15th June 2021
# 1                                                NaN
# 2  (cid:120) Pharmeasy shall provide a web\nbased...
#
#                                                Omron  \
# 0                                      1st July 2021
# 1                                                NaN
# 2  (cid:120) Phable and Omron to\ncollaborate and...
#
#                                    Prima Diagnostics
# 0                                 15th December 2020
# 1                                                NaN
# 2  (cid:120) Prima Diagnostics shall provide\ndel...
#
# Sheet Name: Table_19
#          Unnamed: 0                                         Unnamed: 1  \
# 0  Revenue\nSharing  (cid:120) For every completed order,\nPhable t...
# 1    Payment\nTerms               (cid:190) Within 45 days of invoice.
# 2          Validity  (cid:190) Valid until one of the parties\ngive...
# 3       Termination  (cid:190) Right to terminate with\nimmediate e...
#
#   (cid:120) Devices include - BP Monitor,\nNebulizer, Weight & BMI, TH,\nTENS, Pulse Oximeter  \
# 0  (cid:120) Device Margin: 37% to 102%\non cost ...
# 1  (cid:190) The product price shall be\npaid to ...
# 2  (cid:190) Valid till 31st March 2022, can\nbe ...
# 3  (cid:190) Right to terminate with\nimmediate e...
#
#   (cid:190) Sample blood tests (Blood,\nSaliva, etc.)\nfor users placing orders on\n(cid:51)(cid:75)(cid:68)(cid:69)(cid:79)(cid:72)(cid:183)(cid:86)(cid:3)(cid:83)(cid:79)(cid:68)(cid:87)(cid:73)(cid:82)(cid:85)(cid:80)
# 0  (cid:120) Prima agrees to pay Phable\nthe foll...
# 1                (cid:190) Within 15 days of invoice
# 2  (cid:190) Valid until 1 year from the\ndate of...
# 3  (cid:190) Right to terminate with\nimmediate e...
#
# Sheet Name: Table_20
#                         Particulars             Group Unnamed: 2       On  \
# 0                               NaN               NaN        NaN  Account
# 1  Unbilled Revenue (Device\nSales)  Order in transit          -      NaN
#
#    Unnamed: 4  Unnamed: 5   <30  Unnamed: 7 Unnamed: 8 30-60  Unnamed: 10  \
# 0         NaN         NaN  days         NaN        NaN  days          NaN
# 1         NaN        0.58   NaN         NaN          -   NaN          NaN
#
#   Unnamed: 11 60-90  Unnamed: 13 Unnamed: 14   >90  Unnamed: 16  Total  \
# 0         NaN  days          NaN         NaN  days          NaN    NaN
# 1           -   NaN          NaN           -   NaN          NaN   0.58
#
#   Unnamed: 18 Share
# 0         NaN     %
# 1       31.5%   NaN
#
# Sheet Name: Table_21
#             Pharmeasy          Commission  -   -.1   -.2   -.3  0.51 0.51.1  \
# 0                1 MG          Commission  -  0.02  0.03     -  0.02   0.07
# 1        Dinka Pharma  B2B Medicine Sales  -  0.01  0.00     -     -   0.01
# 2            Dia Plus  B2B Medicine Sales  -     -     -     -  0.01   0.01
# 3  Family Tree Pharma  B2B Medicine Sales  -  0.00  0.00  0.00  0.00   0.01
# 4        Pharma Bliss  B2B Medicine Sales  -     -     -  0.00  0.01   0.01
#
#   28.1%
# 0  4.0%
# 1  0.6%
# 2  0.6%
# 3  0.5%
# 4  0.4%
#
# Sheet Name: Table_22
#                Particulars                 Group Unnamed: 2       On  \
# 0                      NaN                   NaN        NaN  Account
# 1    Roche Diabetics\nCare      Device Inventory          -      NaN
# 2  Mahendra Drug\nAgencies    B2B Medicine Sales          -      NaN
# 3              Karbon Card  Credit Card Payables       0.56      NaN
# 4           Provision COGS      Order in transit       0.40      NaN
#
#    Unnamed: 4 Unnamed: 5   <30  Unnamed: 7 Unnamed: 8 30-60  Unnamed: 10  \
# 0         NaN        NaN  days         NaN        NaN  days          NaN
# 1         NaN       0.50   NaN         NaN       0.12   NaN          NaN
# 2         NaN       0.04   NaN         NaN       0.04   NaN          NaN
# 3         NaN          -   NaN         NaN          -   NaN          NaN
# 4         NaN          -   NaN         NaN          -   NaN          NaN
#
#   Unnamed: 11 60-90  Unnamed: 13 Unnamed: 14   >90  Unnamed: 16 Total Share %
# 0         NaN  days          NaN         NaN  days          NaN   NaN     NaN
# 1           -   NaN          NaN        0.02   NaN          NaN  0.64   17.3%
# 2        0.03   NaN          NaN        0.46   NaN          NaN  0.57   15.3%
# 3           -   NaN          NaN           -   NaN          NaN  0.56   15.1%
# 4           -   NaN          NaN           -   NaN          NaN  0.40   10.7%
#
# Sheet Name: Table_23
#   Unnamed: 0  Company  Unnamed: 2  \
# 0   BeatO(1)      NaN         NaN
#
#                                           Unnamed: 3  Business Overview  \
# 0  BeatO is a diabetes management platform with r...                NaN
#
#    Unnamed: 5                                         Unnamed: 6  Revenue
# 0         NaN  INR ~48 Cr\n(cid:11)(cid:50)(cid:70)(cid:87)(c...      NaN
#
# Sheet Name: Table_24
#       eKincare  \
# 0  Afford Plan
# 1   Healthplix
#
#   eKincare is an online employee health benefits platform. It helps patients to\nmanage their healthcare records. Based on the analytics, the company\nprovides personalized healthcare plans to individuals.  \
# 0  Affordplan is a savings and financial planning...
# 1  Healthplix provides an electronic medical reco...
#
#    INR ~20Cr\n(FY21)
# 0  INR 7.2Cr\n(FY20)
# 1  INR 5.4Cr\n(FY20)
#
# Sheet Name: Table_25
#              Particulars     Unnamed: 1  Revenue Lines           Unnamed: 3  \
# 0                    NaN  Device\nSales            NaN  Medicine\nSales (1)
# 1                    NaN            NaN            NaN                  NaN
# 2                    NaN            NaN            NaN                  NaN
# 3  Revenue\nContribution            46%            NaN                   3%
# 4                Revenue           100%            NaN                 100%
#
#   Unnamed: 4         Unnamed: 5  Unnamed: 6        Unnamed: 7  \
# 0        NaN             Doctor         NaN  Diagnostic\nLabs
# 1        NaN    Consultations &         NaN               NaN
# 2        NaN  Subscriptions (2)         NaN               NaN
# 3        30%                NaN         NaN               11%
# 4       100%                NaN         NaN              100%
#
#              Unnamed: 8
# 0  Health and\nWellness
# 1                   NaN
# 2                   NaN
# 3                    5%
# 4                  100%
#
# Sheet Name: Table_26
#           ⑦\nParticulars    Unnamed: 1  Revenue Lines          Unnamed: 3  \
# 0                    NaN  Device Sales            NaN  Medicine\nSales(1)
# 1                    NaN           NaN            NaN                 NaN
# 2                    NaN           NaN            NaN                 NaN
# 3  Revenue\nContribution           24%            NaN                 27%
# 4                Revenue          100%            NaN                100%
#
#   Unnamed: 4       Unnamed: 5  Unnamed: 6 Unnamed: 7        Unnamed: 8  \
# 0        NaN           Doctor         NaN  Insurance  Diagnostic\nLabs
# 1        NaN  Consultations &         NaN        NaN               NaN
# 2        NaN    Subscriptions         NaN        NaN               NaN
# 3        23%              NaN         NaN       0.3%                7%
# 4       100%              NaN         NaN       100%              100%
#
#   Unnamed: 9 Unnamed: 10
# 0        NaN      Health
# 1        NaN         and
# 2        NaN    Wellness
# 3         5%         NaN
# 4       100%         NaN
#
# Sheet Name: Table_27
#                                           Unnamed: 0      Unnamed: 1
# 0                                                NaN  About Industry
# 1  Chronic Disease/ Non-Communicable Disease (NCD...             NaN
#
# Sheet Name: Table_28
#                Unnamed: 0                                         Unnamed: 1  \
# 0  Year of\nincorporation                                               2017
# 1          Business Model                                              B2B2C
# 2          Core Offerings               Telemedicine,\nAppointment\nBookings
# 3                   Stage                                           Series A
# 4               Investors  Kalaari, SOSV,\nManipal\nHospitals,\nFresco Ca...
#
#                                           Unnamed: 2  \
# 0                                               2015
# 1                                         B2C, B2B2C
# 2  Telemedicine,\nCorporate\nhealth benefit\nprog...
# 3                                           Series B
# 4  Rebright,\nBessemer,\nMilliways,\nJAFCO Asia,\...
#
#                                           Unnamed: 3  \
# 0                                               2017
# 1                                         B2C, B2B2C
# 2  Telemedicine,\nCorporate\nhealth benefit\nprog...
# 3                                           Series C
# 4  Stellaris,\nPrime,\nBeenext,\nHeritas, SBI\nIn...
#
#                                       Unnamed: 4  \
# 0                                           2008
# 1                                            B2C
# 2           Appointment\nbookings,\nTelemedicine
# 3                                       Series D
# 4  Sequoia, Tencent,\nMatrix, Sofina, AIA\nGroup
#
#                                           Unnamed: 5
# 0                                               2014
# 1                                              B2B2C
# 2                Corporate\nhealth benefit\nprograms
# 3                                           Series A
# 4  Endiya\nPartners,\nTouchstone,\nVentureast,\nE...
#
# Sheet Name: Table_29
#   Exit Revenue INR Cr (MRR)\nFinancial year 600 800 1000 1200\nYear of Exercise Jun-25 31.6% 35.6% 38.8% 38.8%\npost Maturity\nJun-26 28.1% 31.2% 33.7% 33.7%\nJun-27 25.6% 28.1% 30.1% 30.1%  \
# 0                                                NaN
# 1  Risk Mitigation\nHigh burn and no clear path t...
#
#             Unnamed: 1
# 0  Risk and Mitigation
# 1                  NaN
#
# Sheet Name: Table_30
#                         Unnamed: 0      Unnamed: 1 Exit Revenue INR Cr (MRR)  \
# 0  Year of Exercise\npost Maturity  Financial year                       600
# 1                              NaN          Jun-25                     31.6%
# 2                              NaN          Jun-26                     28.1%
# 3                              NaN          Jun-27                     25.6%
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0        800       1000       1200
# 1      35.6%      38.8%      38.8%
# 2      31.2%      33.7%      33.7%
# 3      28.1%      30.1%      30.1%
#
# Sheet Name: Table_31
#                                           Unnamed: 0  Risk  Unnamed: 2  \
# 0  High burn and no clear path to profitability\n...   NaN         NaN
# 1  No clear product market fit\nPhable has starte...   NaN         NaN
# 2  Investor quality and scalability\nThe current ...   NaN         NaN
#
#                                           Unnamed: 3  Mitigation
# 0  (cid:190) Phable is focusing strongly on custo...         NaN
# 1  (cid:190) Phable is creating a niche in the ch...         NaN
# 2  (cid:190) Phable is raising $17 Mn in December...         NaN
#
# Sheet Name: Table_32
#   their customer acquisition and strategic\nacquisitions in the near future.  \
# 0                                                NaN
# 1  Debt Protection\nPhable is raising $17 mn (~IN...
#
#                      Unnamed: 1
# 0  Rationale for Recommendation
# 1                           NaN
#
# Sheet Name: Table_33
#   Furthermore, the company is building products for doctors and clinics, in addition to patients, who are already on the\nplatform and has over 4,000 active doctors using Phable already.  \
# 0                                                NaN
# 1  Saurabh Pandey, CEO and Co-founder, Akna Medic...
#
#          Unnamed: 1
# 0  Reference Checks
# 1               NaN
